# %% [markdown]
# # Random-Trials Approach - Night Classifier

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc as sc
from time import time
from collections import Counter

# %%
d = {}
bus_stop_names = ["Medavakkam", "Mogappair East", "Pari Salai"]
for it in xrange(1, len(bus_stop_names)+1):
    d[it] = bus_stop_names[it-1]

# %%
def image_resize(im):
    im = sc.imresize(im, (32, 32, 3))
    return im

# %%
X_train = np.array(image_resize(plt.imread("./TrainDataNight/Train1.jpg")).flatten().astype("float32"))
for i in range(2, 271):
    if i % 25 == 0:
        print "Reading train image " + str(i)
    img = plt.imread("./TrainDataNight/Train" + str(i) + ".jpg")
    X_train = np.vstack((X_train,image_resize(img).flatten().astype("float32")))
print len(X_train)
# Out:
# Reading train image 25
# Reading train image 50
# Reading train image 75
# Reading train image 100
# Reading train image 125
# Reading train image 150
# Reading train image 175
# Reading train image 200
# Reading train image 225
# Reading train image 250
# 270

# %%
X_train = X_train / 255.0

# %%
y_train = []
for bus_stop in range(1, 4):
    for train_images in range(90):
        y_train.append(bus_stop)
y_train = np.array(y_train)

# %%
def compute_distances(X_train, X):
    X = np.array(X)
    X = X.astype("float32")
    X /= 255.0
    num_test = X.shape[0]
    num_train = X_train.shape[0]
    dists = np.zeros((num_test, num_train))
    dists = np.sqrt((np.square(X).sum(axis=1, keepdims=True)) - (2*X.dot(X_train.T)) + (np.square(X_train).sum(axis=1)))
    return dists

# %%
for n_images in [2, 3, 5, 7, 9, 11]:
    t1 = time()
    for iterx in range(100):
        print "Iter: " + str(iterx)
        class_name = np.random.randint(1, 4)
        print "Class name: " + str(d[class_name]), "; No. of Images: " + str(n_images)
        print
        X_test = np.zeros((n_images, np.prod(X_train.shape[1:])))
        x = 0
        if class_name == 1:
            test_images = np.random.randint(1, 31, size=n_images)
            for i in test_images:
                X_test_temp = image_resize(plt.imread("./TestDataNight/Medavakkam/Test" + str(i) + ".jpg")).flatten()
                X_test[x, :] = X_test_temp
                x += 1
        elif class_name == 2:
            test_images = np.random.randint(1, 31, size=n_images)
            for i in test_images:
                X_test_temp = image_resize(plt.imread("./TestDataNight/Mogappair East/Test" + str(i) + ".jpg")).flatten()
                X_test[x, :] = X_test_temp
                x += 1
        elif class_name == 3:
            test_images = np.random.randint(1, 31, size=n_images)
            for i in test_images:
                X_test_temp = image_resize(plt.imread("./TestDataNight/Pari Salai/Test" + str(i) + ".jpg")).flatten()
                X_test[x, :] = X_test_temp
                x += 1

        dis = compute_distances(X_train, X_test)

        for k in range(1, 6):
            count = 0
            correct_classes = []
            for i in range(dis.shape[0]):
                l = y_train[np.argsort(dis[i, :])].flatten()
                closest_y = l[:k]
                correct_classes.append(Counter(closest_y).most_common(1)[0][0])
            correct_classes = np.array(correct_classes)
            #print l[:10]
            for v in range(correct_classes.shape[0]):
                if correct_classes[v] == class_name:
                    count += 1
            print "k = " + str(k)
            print "Predicted as: ",
            for cc in correct_classes:
                print d[cc] + ", ",
            print
            print "Groundtruth : " + str(d[class_name])
            accuracy = float(count) / dis.shape[0]
            print "Accuracy: " + str(accuracy)
            print
        #print
    t2 = time()
    print "Time Taken: " + str(t2-t1)
    print
# Out:
# Iter: 0
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 1
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 2
# Class name: Pari Salai ; No. of Images: 2
#
# k = 1
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# Iter: 3
# Class name: Pari Salai ; No. of Images: 2
#
# k = 1
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# Iter: 4
# Class name: Pari Salai ; No. of Images: 2
#
# k = 1
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# Iter: 5
# Class name: Pari Salai ; No. of Images: 2
#
# k = 1
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# Iter: 6
# Class name: Pari Salai ; No. of Images: 2
#
# k = 1
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# Iter: 7
# Class name: Pari Salai ; No. of Images: 2
#
# k = 1
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Pari Salai,  Mogappair East,
# Groundtruth : Pari Salai
# Accuracy: 0.5
#
# k = 5
# Predicted as:  Pari Salai,  Mogappair East,
# Groundtruth : Pari Salai
# Accuracy: 0.5
#
# Iter: 8
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 9
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 10
# Class name: Pari Salai ; No. of Images: 2
#
# k = 1
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# Iter: 11
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 12
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 13
# Class name: Pari Salai ; No. of Images: 2
#
# k = 1
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# Iter: 14
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 15
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 16
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 17
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 18
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 19
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 20
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 21
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 22
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 23
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 24
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 25
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 26
# Class name: Pari Salai ; No. of Images: 2
#
# k = 1
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# Iter: 27
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 28
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 29
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 30
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 31
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 32
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 33
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 34
# Class name: Pari Salai ; No. of Images: 2
#
# k = 1
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 0.5
#
# k = 5
# Predicted as:  Mogappair East,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 0.5
#
# Iter: 35
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 36
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 37
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 38
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 39
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 40
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 41
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 42
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 43
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 44
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 45
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 46
# Class name: Pari Salai ; No. of Images: 2
#
# k = 1
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# Iter: 47
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 48
# Class name: Pari Salai ; No. of Images: 2
#
# k = 1
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# Iter: 49
# Class name: Pari Salai ; No. of Images: 2
#
# k = 1
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# Iter: 50
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 51
# Class name: Pari Salai ; No. of Images: 2
#
# k = 1
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 0.5
#
# k = 5
# Predicted as:  Mogappair East,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 0.5
#
# Iter: 52
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 53
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 54
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 55
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Medavakkam,
# Groundtruth : Mogappair East
# Accuracy: 0.5
#
# k = 5
# Predicted as:  Mogappair East,  Medavakkam,
# Groundtruth : Mogappair East
# Accuracy: 0.5
#
# Iter: 56
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 57
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 58
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 59
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 60
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 61
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 62
# Class name: Pari Salai ; No. of Images: 2
#
# k = 1
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# Iter: 63
# Class name: Pari Salai ; No. of Images: 2
#
# k = 1
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# Iter: 64
# Class name: Pari Salai ; No. of Images: 2
#
# k = 1
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# Iter: 65
# Class name: Pari Salai ; No. of Images: 2
#
# k = 1
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# Iter: 66
# Class name: Pari Salai ; No. of Images: 2
#
# k = 1
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# Iter: 67
# Class name: Pari Salai ; No. of Images: 2
#
# k = 1
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# Iter: 68
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 69
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 70
# Class name: Pari Salai ; No. of Images: 2
#
# k = 1
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# Iter: 71
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 72
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 73
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 74
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 75
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 76
# Class name: Pari Salai ; No. of Images: 2
#
# k = 1
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# Iter: 77
# Class name: Pari Salai ; No. of Images: 2
#
# k = 1
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# Iter: 78
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Medavakkam,
# Groundtruth : Mogappair East
# Accuracy: 0.5
#
# k = 5
# Predicted as:  Mogappair East,  Medavakkam,
# Groundtruth : Mogappair East
# Accuracy: 0.5
#
# Iter: 79
# Class name: Pari Salai ; No. of Images: 2
#
# k = 1
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# Iter: 80
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 81
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 82
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 83
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 84
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 85
# Class name: Pari Salai ; No. of Images: 2
#
# k = 1
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# Iter: 86
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 87
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 88
# Class name: Mogappair East ; No. of Images: 2
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 89
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 90
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 91
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 92
# Class name: Medavakkam ; No. of Images: 2
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 93
# Class name: Pari Salai ; No. of Images: 2
#
# k = 1
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Pari Salai,  Pari Salai,
# ...
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 87
# Class name: Medavakkam ; No. of Images: 11
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 88
# Class name: Mogappair East ; No. of Images: 11
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 89
# Class name: Medavakkam ; No. of Images: 11
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 90
# Class name: Medavakkam ; No. of Images: 11
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 91
# Class name: Medavakkam ; No. of Images: 11
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 92
# Class name: Mogappair East ; No. of Images: 11
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 93
# Class name: Mogappair East ; No. of Images: 11
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Medavakkam,  Mogappair East,  Medavakkam,  Mogappair East,  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 0.818181818182
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Medavakkam,  Mogappair East,  Medavakkam,  Mogappair East,  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 0.818181818182
#
# Iter: 94
# Class name: Pari Salai ; No. of Images: 11
#
# k = 1
# Predicted as:  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,  Pari Salai,
# Groundtruth : Pari Salai
# Accuracy: 1.0
#
# Iter: 95
# Class name: Medavakkam ; No. of Images: 11
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 96
# Class name: Medavakkam ; No. of Images: 11
#
# k = 1
# Predicted as:  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,  Medavakkam,
# Groundtruth : Medavakkam
# Accuracy: 1.0
#
# Iter: 97
# Class name: Mogappair East ; No. of Images: 11
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 98
# Class name: Mogappair East ; No. of Images: 11
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Iter: 99
# Class name: Mogappair East ; No. of Images: 11
#
# k = 1
# Predicted as:  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 2
# Predicted as:  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 3
# Predicted as:  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 4
# Predicted as:  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# k = 5
# Predicted as:  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,  Mogappair East,
# Groundtruth : Mogappair East
# Accuracy: 1.0
#
# Time Taken: 2.50933694839
