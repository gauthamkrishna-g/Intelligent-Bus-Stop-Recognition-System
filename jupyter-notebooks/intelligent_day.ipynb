# %% [markdown]
# # Intelligent Approach - Day Classifier

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc as sc
from time import time
from collections import Counter

# %%
d = {}
bus_stop_names = ["JJ Nagar East", "Anna Nagar West Depot", "Collector Nagar", "Mogappair", "Thirumangalam",
                  "Gurunath Stores", "Incubation Centre", "SOMCA Block"]
for it in xrange(1, len(bus_stop_names)+1):
    d[it] = bus_stop_names[it-1]

# %%
def image_resize(im):
    im = sc.imresize(im, (32, 32, 3))
    return im

# %%
X_train = np.array(image_resize(plt.imread("./TrainDataDay/Train1.jpg")).flatten().astype("float32"))
for i in range(2, 721):
    if i % 25 == 0:
        print "Reading train image " + str(i)
    img = plt.imread("./TrainDataDay/Train" + str(i) + ".jpg")
    X_train = np.vstack((X_train,image_resize(img).flatten().astype("float32")))
print len(X_train)
# Out:
# Reading train image 25
# Reading train image 50
# Reading train image 75
# Reading train image 100
# Reading train image 125
# Reading train image 150
# Reading train image 175
# Reading train image 200
# Reading train image 225
# Reading train image 250
# Reading train image 275
# Reading train image 300
# Reading train image 325
# Reading train image 350
# Reading train image 375
# Reading train image 400
# Reading train image 425
# Reading train image 450
# Reading train image 475
# Reading train image 500
# Reading train image 525
# Reading train image 550
# Reading train image 575
# Reading train image 600
# Reading train image 625
# Reading train image 650
# Reading train image 675
# Reading train image 700
# 720

# %%
X_train = X_train / 255.0

# %%
y_train = []
for bus_stop in range(1, 9):
    for train_images in range(90):
        y_train.append(bus_stop)
y_train = np.array(y_train)
print y_train.shape
# Out:
# (720,)

# %%
def get_one_image(class_name, rand_num):
    rand_num=rand_num[0]
    if class_name == 1:
        return image_resize(plt.imread("./TestDataDay/7H/Test" + str(rand_num) + ".jpg")).flatten()
    if class_name == 2:
        return image_resize(plt.imread("./TestDataDay/AN West Depot/Test" + str(rand_num) + ".jpg")).flatten()
    if class_name == 3:
        return image_resize(plt.imread("./TestDataDay/Collector Nagar/Test" + str(rand_num) + ".jpg")).flatten()
    if class_name == 4:
        return image_resize(plt.imread("./TestDataDay/Mogappair East/Test" + str(rand_num) + ".jpg")).flatten()
    if class_name == 5:
        return image_resize(plt.imread("./TestDataDay/Thirumangalam/Test" + str(rand_num) + ".jpg")).flatten()
    if class_name == 6:
        return image_resize(plt.imread("./TestDataDay/Gurunath/Test" + str(rand_num) + ".jpg")).flatten()
    if class_name == 7:
        return image_resize(plt.imread("./TestDataDay/Incubation Centre/Test" + str(rand_num) + ".jpg")).flatten()
    if class_name == 8:
        return image_resize(plt.imread("./TestDataDay/SOMCA/Test" + str(rand_num) + ".jpg")).flatten()

# %%
def compute_distances(X_train, X):
    X = np.array(X)
    X = X.astype("float32")
    X /= 255.0
    num_test = X.shape[0]
    num_train = X_train.shape[0]
    dists = np.zeros((num_test, num_train))
    dists = np.sqrt((np.square(X).sum(axis=1, keepdims=True)) - (2*X.dot(X_train.T)) + (np.square(X_train).sum(axis=1)))
    return dists

# %%
for n_images in [2]:
    t1 = time()
    for iterx in range(100):
        print "Iter: " + str(iterx)
        class_name = np.random.randint(1, 9)
        print "Class name: " + str(d[class_name]), "; No. of Images: " + str(n_images)
        X_test = np.zeros((n_images, np.prod(X_train.shape[1:])))
        x = 0
        if class_name == 1:
            test_images = np.random.randint(1, 31, size=n_images)
            for i in test_images:
                X_test_temp = image_resize(plt.imread("./TestDataDay/7H/Test" + str(i) + ".jpg")).flatten()
                X_test[x, :] = X_test_temp
                x += 1
        elif class_name == 2:
            test_images = np.random.randint(1, 31, size=n_images)
            for i in test_images:
                X_test_temp = image_resize(plt.imread("./TestDataDay/AN West Depot/Test" + str(i) + ".jpg")).flatten()
                X_test[x, :] = X_test_temp
                x += 1
        elif class_name == 3:
            test_images = np.random.randint(1, 31, size=n_images)
            for i in test_images:
                X_test_temp = image_resize(plt.imread("./TestDataDay/Collector Nagar/Test" + str(i) + ".jpg")).flatten()
                X_test[x, :] = X_test_temp
                x += 1
        elif class_name == 4:
            test_images = np.random.randint(1, 31, size=n_images)
            for i in test_images:
                X_test_temp = image_resize(plt.imread("./TestDataDay/Mogappair East/Test" + str(i) + ".jpg")).flatten()
                X_test[x, :] = X_test_temp
                x += 1
        elif class_name == 5:
            test_images = np.random.randint(1, 31, size=n_images)
            for i in test_images:
                X_test_temp = image_resize(plt.imread("./TestDataDay/Thirumangalam/Test" + str(i) + ".jpg")).flatten()
                X_test[x, :] = X_test_temp
                x += 1
        elif class_name == 6:
            test_images = np.random.randint(1, 31, size=n_images)
            for i in test_images:
                X_test_temp = image_resize(plt.imread("./TestDataDay/Gurunath/Test" + str(i) + ".jpg")).flatten()
                X_test[x, :] = X_test_temp
                x += 1
        elif class_name == 7:
            test_images = np.random.randint(1, 31, size=n_images)
            for i in test_images:
                X_test_temp = image_resize(plt.imread("./TestDataDay/Incubation Centre/Test" + str(i) + ".jpg")).flatten()
                X_test[x, :] = X_test_temp
                x += 1
        elif class_name == 8:
            test_images = np.random.randint(1, 31, size=n_images)
            for i in test_images:
                X_test_temp = image_resize(plt.imread("./TestDataDay/SOMCA/Test" + str(i) + ".jpg")).flatten()
                X_test[x, :] = X_test_temp
                x += 1

        dis = compute_distances(X_train, X_test)

        for k in range(1, 2):
            count = 0
            correct_classes = []
            for i in range(dis.shape[0]):
                l = y_train[np.argsort(dis[i, :])].flatten()
                closest_y = l[:k]
                correct_classes.append(Counter(closest_y).most_common(1)[0][0])
            correct_classes = np.array(correct_classes)
            #print "Closest 10 images : " + str(l[:10])
            print "Predicted as: ",
            for cc in correct_classes:
                print d[cc] + ", ",
            print
            print "Groundtruth: " + str(d[class_name])

        for var in range(1, 9):
            print "Accuracy: " + str(Counter(correct_classes).most_common(1)[0][1] / float(len(correct_classes)))
            if Counter(correct_classes).most_common(1)[0][1] / float(len(correct_classes)) > 0.5:
                break
            else:
                print "Fetching New Image"
                new_image_no = np.random.randint(1, 31, size=1)
                while new_image_no in test_images:
                    new_image_no = np.random.randint(1, 31, size=1)
                #print test_images, new_image_no
                list(test_images).append(new_image_no)
                new_test = get_one_image(class_name=class_name, rand_num=new_image_no)
                X_test = np.vstack((X_test, new_test))
                #print X_test.shape
                dis_new = compute_distances(X_train, X_test)
                correct_classes1 = []
                for ii in range(dis_new.shape[0]):
                    l1 = y_train[np.argsort(dis_new[ii, :])].flatten()
                    closest_y1 = l1[:k]
                    correct_classes1.append(Counter(closest_y1).most_common(1)[0][0])
                if Counter(correct_classes1).most_common(1)[0][1] / float(len(correct_classes1)) < 0.5:
                    print "Back again" + str(Counter(correct_classes1).most_common(1)[0][1] / float(len(correct_classes1)))
                    print "Predicted as: ",
                    for cc in correct_classes1:
                        print d[cc] + ", ",
                    print 
                    #print correct_classes1,
                    print "Ground Truth: " + str(d[class_name])
                else:
                    print "Predicted as : ",
                    for cc in correct_classes1:
                        print d[cc] + ", ",
                    print
                    #print correct_classes1,
                    print "Ground Truth: " + str(d[class_name])
                    print "Accuracy now is: " + str(Counter(correct_classes1).most_common(1)[0][1] / float(len(correct_classes1)))
                    break
        print
    t2 = time()
    print "Time Taken: " + str(t2-t1)
# Out:
# Iter: 0
# Class name: Thirumangalam ; No. of Images: 2
# Predicted as:  Thirumangalam,  Thirumangalam,
# Groundtruth: Thirumangalam
# Accuracy: 1.0
#
# Iter: 1
# Class name: Mogappair ; No. of Images: 2
# Predicted as:  Mogappair,  Mogappair,
# Groundtruth: Mogappair
# Accuracy: 1.0
#
# Iter: 2
# Class name: Incubation Centre ; No. of Images: 2
# Predicted as:  Incubation Centre,  Incubation Centre,
# Groundtruth: Incubation Centre
# Accuracy: 1.0
#
# Iter: 3
# Class name: Collector Nagar ; No. of Images: 2
# Predicted as:  Collector Nagar,  Collector Nagar,
# Groundtruth: Collector Nagar
# Accuracy: 1.0
#
# Iter: 4
# Class name: JJ Nagar East ; No. of Images: 2
# Predicted as:  JJ Nagar East,  JJ Nagar East,
# Groundtruth: JJ Nagar East
# Accuracy: 1.0
#
# Iter: 5
# Class name: Gurunath Stores ; No. of Images: 2
# Predicted as:  Gurunath Stores,  Gurunath Stores,
# Groundtruth: Gurunath Stores
# Accuracy: 1.0
#
# Iter: 6
# Class name: Incubation Centre ; No. of Images: 2
# Predicted as:  Incubation Centre,  Incubation Centre,
# Groundtruth: Incubation Centre
# Accuracy: 1.0
#
# Iter: 7
# Class name: Thirumangalam ; No. of Images: 2
# Predicted as:  Thirumangalam,  Thirumangalam,
# Groundtruth: Thirumangalam
# Accuracy: 1.0
#
# Iter: 8
# Class name: Gurunath Stores ; No. of Images: 2
# Predicted as:  Gurunath Stores,  Gurunath Stores,
# Groundtruth: Gurunath Stores
# Accuracy: 1.0
#
# Iter: 9
# Class name: Thirumangalam ; No. of Images: 2
# Predicted as:  Thirumangalam,  Thirumangalam,
# Groundtruth: Thirumangalam
# Accuracy: 1.0
#
# Iter: 10
# Class name: Gurunath Stores ; No. of Images: 2
# Predicted as:  Gurunath Stores,  Gurunath Stores,
# Groundtruth: Gurunath Stores
# Accuracy: 1.0
#
# Iter: 11
# Class name: Collector Nagar ; No. of Images: 2
# Predicted as:  Collector Nagar,  Collector Nagar,
# Groundtruth: Collector Nagar
# Accuracy: 1.0
#
# Iter: 12
# Class name: Anna Nagar West Depot ; No. of Images: 2
# Predicted as:  Anna Nagar West Depot,  Anna Nagar West Depot,
# Groundtruth: Anna Nagar West Depot
# Accuracy: 1.0
#
# Iter: 13
# Class name: Incubation Centre ; No. of Images: 2
# Predicted as:  Incubation Centre,  Incubation Centre,
# Groundtruth: Incubation Centre
# Accuracy: 1.0
#
# Iter: 14
# Class name: Gurunath Stores ; No. of Images: 2
# Predicted as:  Gurunath Stores,  Gurunath Stores,
# Groundtruth: Gurunath Stores
# Accuracy: 1.0
#
# Iter: 15
# Class name: Anna Nagar West Depot ; No. of Images: 2
# Predicted as:  Anna Nagar West Depot,  Anna Nagar West Depot,
# Groundtruth: Anna Nagar West Depot
# Accuracy: 1.0
#
# Iter: 16
# Class name: Mogappair ; No. of Images: 2
# Predicted as:  Mogappair,  Mogappair,
# Groundtruth: Mogappair
# Accuracy: 1.0
#
# Iter: 17
# Class name: SOMCA Block ; No. of Images: 2
# Predicted as:  SOMCA Block,  SOMCA Block,
# Groundtruth: SOMCA Block
# Accuracy: 1.0
#
# Iter: 18
# Class name: Thirumangalam ; No. of Images: 2
# Predicted as:  Thirumangalam,  Thirumangalam,
# Groundtruth: Thirumangalam
# Accuracy: 1.0
#
# Iter: 19
# Class name: Gurunath Stores ; No. of Images: 2
# Predicted as:  Gurunath Stores,  Gurunath Stores,
# Groundtruth: Gurunath Stores
# Accuracy: 1.0
#
# Iter: 20
# Class name: Gurunath Stores ; No. of Images: 2
# Predicted as:  Gurunath Stores,  Gurunath Stores,
# Groundtruth: Gurunath Stores
# Accuracy: 1.0
#
# Iter: 21
# Class name: JJ Nagar East ; No. of Images: 2
# Predicted as:  JJ Nagar East,  JJ Nagar East,
# Groundtruth: JJ Nagar East
# Accuracy: 1.0
#
# Iter: 22
# Class name: Gurunath Stores ; No. of Images: 2
# Predicted as:  Gurunath Stores,  Gurunath Stores,
# Groundtruth: Gurunath Stores
# Accuracy: 1.0
#
# Iter: 23
# Class name: Incubation Centre ; No. of Images: 2
# Predicted as:  Incubation Centre,  Incubation Centre,
# Groundtruth: Incubation Centre
# Accuracy: 1.0
#
# Iter: 24
# Class name: Anna Nagar West Depot ; No. of Images: 2
# Predicted as:  Anna Nagar West Depot,  Mogappair,
# Groundtruth: Anna Nagar West Depot
# Accuracy: 0.5
# Fetching New Image
# Predicted as :  Anna Nagar West Depot,  Mogappair,  Anna Nagar West Depot,
# Ground Truth: Anna Nagar West Depot
# Accuracy now is: 0.666666666667
#
# Iter: 25
# Class name: Thirumangalam ; No. of Images: 2
# Predicted as:  Thirumangalam,  Thirumangalam,
# Groundtruth: Thirumangalam
# Accuracy: 1.0
#
# Iter: 26
# Class name: Gurunath Stores ; No. of Images: 2
# Predicted as:  Gurunath Stores,  Gurunath Stores,
# Groundtruth: Gurunath Stores
# Accuracy: 1.0
#
# Iter: 27
# Class name: Collector Nagar ; No. of Images: 2
# Predicted as:  Collector Nagar,  Collector Nagar,
# Groundtruth: Collector Nagar
# Accuracy: 1.0
#
# Iter: 28
# Class name: Gurunath Stores ; No. of Images: 2
# Predicted as:  Gurunath Stores,  Gurunath Stores,
# Groundtruth: Gurunath Stores
# Accuracy: 1.0
#
# Iter: 29
# Class name: JJ Nagar East ; No. of Images: 2
# Predicted as:  JJ Nagar East,  JJ Nagar East,
# Groundtruth: JJ Nagar East
# Accuracy: 1.0
#
# Iter: 30
# Class name: SOMCA Block ; No. of Images: 2
# Predicted as:  SOMCA Block,  SOMCA Block,
# Groundtruth: SOMCA Block
# Accuracy: 1.0
#
# Iter: 31
# Class name: Anna Nagar West Depot ; No. of Images: 2
# Predicted as:  Anna Nagar West Depot,  Anna Nagar West Depot,
# Groundtruth: Anna Nagar West Depot
# Accuracy: 1.0
#
# Iter: 32
# Class name: Mogappair ; No. of Images: 2
# Predicted as:  Mogappair,  Mogappair,
# Groundtruth: Mogappair
# Accuracy: 1.0
#
# Iter: 33
# Class name: Incubation Centre ; No. of Images: 2
# Predicted as:  Incubation Centre,  Incubation Centre,
# Groundtruth: Incubation Centre
# Accuracy: 1.0
#
# Iter: 34
# Class name: Gurunath Stores ; No. of Images: 2
# Predicted as:  Gurunath Stores,  Gurunath Stores,
# Groundtruth: Gurunath Stores
# Accuracy: 1.0
#
# Iter: 35
# Class name: Thirumangalam ; No. of Images: 2
# Predicted as:  Thirumangalam,  Thirumangalam,
# Groundtruth: Thirumangalam
# Accuracy: 1.0
#
# Iter: 36
# Class name: Collector Nagar ; No. of Images: 2
# Predicted as:  Collector Nagar,  Collector Nagar,
# Groundtruth: Collector Nagar
# Accuracy: 1.0
#
# Iter: 37
# Class name: Gurunath Stores ; No. of Images: 2
# Predicted as:  Gurunath Stores,  Gurunath Stores,
# Groundtruth: Gurunath Stores
# Accuracy: 1.0
#
# Iter: 38
# Class name: Thirumangalam ; No. of Images: 2
# Predicted as:  Thirumangalam,  Thirumangalam,
# Groundtruth: Thirumangalam
# Accuracy: 1.0
#
# Iter: 39
# Class name: Collector Nagar ; No. of Images: 2
# Predicted as:  Collector Nagar,  Collector Nagar,
# Groundtruth: Collector Nagar
# Accuracy: 1.0
#
# Iter: 40
# Class name: Anna Nagar West Depot ; No. of Images: 2
# Predicted as:  Anna Nagar West Depot,  Anna Nagar West Depot,
# Groundtruth: Anna Nagar West Depot
# Accuracy: 1.0
#
# Iter: 41
# Class name: Incubation Centre ; No. of Images: 2
# Predicted as:  Incubation Centre,  Incubation Centre,
# Groundtruth: Incubation Centre
# Accuracy: 1.0
#
# Iter: 42
# Class name: Mogappair ; No. of Images: 2
# Predicted as:  Mogappair,  Mogappair,
# Groundtruth: Mogappair
# Accuracy: 1.0
#
# Iter: 43
# Class name: JJ Nagar East ; No. of Images: 2
# Predicted as:  JJ Nagar East,  JJ Nagar East,
# Groundtruth: JJ Nagar East
# Accuracy: 1.0
#
# Iter: 44
# Class name: Anna Nagar West Depot ; No. of Images: 2
# Predicted as:  Anna Nagar West Depot,  Anna Nagar West Depot,
# Groundtruth: Anna Nagar West Depot
# Accuracy: 1.0
#
# Iter: 45
# Class name: Mogappair ; No. of Images: 2
# Predicted as:  Mogappair,  Mogappair,
# Groundtruth: Mogappair
# Accuracy: 1.0
#
# Iter: 46
# Class name: Mogappair ; No. of Images: 2
# Predicted as:  Mogappair,  Mogappair,
# Groundtruth: Mogappair
# Accuracy: 1.0
#
# Iter: 47
# Class name: Collector Nagar ; No. of Images: 2
# Predicted as:  Collector Nagar,  Collector Nagar,
# Groundtruth: Collector Nagar
# Accuracy: 1.0
#
# Iter: 48
# Class name: Collector Nagar ; No. of Images: 2
# Predicted as:  Collector Nagar,  Collector Nagar,
# Groundtruth: Collector Nagar
# Accuracy: 1.0
#
# Iter: 49
# Class name: Thirumangalam ; No. of Images: 2
# Predicted as:  Thirumangalam,  Thirumangalam,
# Groundtruth: Thirumangalam
# Accuracy: 1.0
#
# Iter: 50
# Class name: Mogappair ; No. of Images: 2
# Predicted as:  Mogappair,  Mogappair,
# Groundtruth: Mogappair
# Accuracy: 1.0
#
# Iter: 51
# Class name: Thirumangalam ; No. of Images: 2
# Predicted as:  Thirumangalam,  Thirumangalam,
# Groundtruth: Thirumangalam
# Accuracy: 1.0
#
# Iter: 52
# Class name: SOMCA Block ; No. of Images: 2
# Predicted as:  SOMCA Block,  SOMCA Block,
# Groundtruth: SOMCA Block
# Accuracy: 1.0
#
# Iter: 53
# Class name: Anna Nagar West Depot ; No. of Images: 2
# Predicted as:  Anna Nagar West Depot,  Anna Nagar West Depot,
# Groundtruth: Anna Nagar West Depot
# Accuracy: 1.0
#
# Iter: 54
# Class name: Thirumangalam ; No. of Images: 2
# Predicted as:  Thirumangalam,  Thirumangalam,
# Groundtruth: Thirumangalam
# Accuracy: 1.0
#
# Iter: 55
# Class name: JJ Nagar East ; No. of Images: 2
# Predicted as:  JJ Nagar East,  JJ Nagar East,
# Groundtruth: JJ Nagar East
# Accuracy: 1.0
#
# Iter: 56
# Class name: Incubation Centre ; No. of Images: 2
# Predicted as:  Incubation Centre,  Incubation Centre,
# Groundtruth: Incubation Centre
# Accuracy: 1.0
#
# Iter: 57
# Class name: JJ Nagar East ; No. of Images: 2
# Predicted as:  JJ Nagar East,  JJ Nagar East,
# Groundtruth: JJ Nagar East
# Accuracy: 1.0
#
# Iter: 58
# Class name: Anna Nagar West Depot ; No. of Images: 2
# Predicted as:  Anna Nagar West Depot,  Anna Nagar West Depot,
# Groundtruth: Anna Nagar West Depot
# Accuracy: 1.0
#
# Iter: 59
# Class name: Thirumangalam ; No. of Images: 2
# Predicted as:  Thirumangalam,  Thirumangalam,
# Groundtruth: Thirumangalam
# Accuracy: 1.0
#
# Iter: 60
# Class name: Anna Nagar West Depot ; No. of Images: 2
# Predicted as:  Anna Nagar West Depot,  Anna Nagar West Depot,
# Groundtruth: Anna Nagar West Depot
# Accuracy: 1.0
#
# Iter: 61
# Class name: Anna Nagar West Depot ; No. of Images: 2
# Predicted as:  Anna Nagar West Depot,  Anna Nagar West Depot,
# Groundtruth: Anna Nagar West Depot
# Accuracy: 1.0
#
# Iter: 62
# Class name: Collector Nagar ; No. of Images: 2
# Predicted as:  Collector Nagar,  Collector Nagar,
# Groundtruth: Collector Nagar
# Accuracy: 1.0
#
# Iter: 63
# Class name: SOMCA Block ; No. of Images: 2
# Predicted as:  SOMCA Block,  SOMCA Block,
# Groundtruth: SOMCA Block
# Accuracy: 1.0
#
# Iter: 64
# Class name: Incubation Centre ; No. of Images: 2
# Predicted as:  Incubation Centre,  Incubation Centre,
# Groundtruth: Incubation Centre
# Accuracy: 1.0
#
# Iter: 65
# Class name: Incubation Centre ; No. of Images: 2
# Predicted as:  Incubation Centre,  Incubation Centre,
# Groundtruth: Incubation Centre
# Accuracy: 1.0
#
# Iter: 66
# Class name: Gurunath Stores ; No. of Images: 2
# Predicted as:  Gurunath Stores,  Gurunath Stores,
# Groundtruth: Gurunath Stores
# Accuracy: 1.0
#
# Iter: 67
# Class name: Gurunath Stores ; No. of Images: 2
# Predicted as:  Gurunath Stores,  Gurunath Stores,
# Groundtruth: Gurunath Stores
# Accuracy: 1.0
#
# Iter: 68
# Class name: Incubation Centre ; No. of Images: 2
# Predicted as:  Incubation Centre,  Incubation Centre,
# Groundtruth: Incubation Centre
# Accuracy: 1.0
#
# Iter: 69
# Class name: Mogappair ; No. of Images: 2
# Predicted as:  Mogappair,  Mogappair,
# Groundtruth: Mogappair
# Accuracy: 1.0
#
# Iter: 70
# Class name: Mogappair ; No. of Images: 2
# Predicted as:  Mogappair,  Mogappair,
# Groundtruth: Mogappair
# Accuracy: 1.0
#
# Iter: 71
# Class name: Gurunath Stores ; No. of Images: 2
# Predicted as:  Gurunath Stores,  Gurunath Stores,
# Groundtruth: Gurunath Stores
# Accuracy: 1.0
#
# Iter: 72
# Class name: Incubation Centre ; No. of Images: 2
# Predicted as:  Incubation Centre,  Incubation Centre,
# Groundtruth: Incubation Centre
# Accuracy: 1.0
#
# Iter: 73
# Class name: Mogappair ; No. of Images: 2
# Predicted as:  Mogappair,  Mogappair,
# Groundtruth: Mogappair
# Accuracy: 1.0
#
# Iter: 74
# Class name: SOMCA Block ; No. of Images: 2
# Predicted as:  SOMCA Block,  SOMCA Block,
# Groundtruth: SOMCA Block
# Accuracy: 1.0
#
# Iter: 75
# Class name: Collector Nagar ; No. of Images: 2
# Predicted as:  Collector Nagar,  Collector Nagar,
# Groundtruth: Collector Nagar
# Accuracy: 1.0
#
# Iter: 76
# Class name: Collector Nagar ; No. of Images: 2
# Predicted as:  Collector Nagar,  Collector Nagar,
# Groundtruth: Collector Nagar
# Accuracy: 1.0
#
# Iter: 77
# Class name: Thirumangalam ; No. of Images: 2
# Predicted as:  Thirumangalam,  Thirumangalam,
# Groundtruth: Thirumangalam
# Accuracy: 1.0
#
# Iter: 78
# Class name: Mogappair ; No. of Images: 2
# Predicted as:  Mogappair,  Mogappair,
# Groundtruth: Mogappair
# Accuracy: 1.0
#
# Iter: 79
# Class name: JJ Nagar East ; No. of Images: 2
# Predicted as:  JJ Nagar East,  JJ Nagar East,
# Groundtruth: JJ Nagar East
# Accuracy: 1.0
#
# Iter: 80
# Class name: Anna Nagar West Depot ; No. of Images: 2
# Predicted as:  Anna Nagar West Depot,  Anna Nagar West Depot,
# Groundtruth: Anna Nagar West Depot
# Accuracy: 1.0
#
# Iter: 81
# Class name: Gurunath Stores ; No. of Images: 2
# Predicted as:  Gurunath Stores,  Gurunath Stores,
# Groundtruth: Gurunath Stores
# Accuracy: 1.0
#
# Iter: 82
# Class name: Anna Nagar West Depot ; No. of Images: 2
# Predicted as:  Anna Nagar West Depot,  Anna Nagar West Depot,
# Groundtruth: Anna Nagar West Depot
# Accuracy: 1.0
#
# Iter: 83
# Class name: Collector Nagar ; No. of Images: 2
# Predicted as:  Collector Nagar,  Collector Nagar,
# Groundtruth: Collector Nagar
# Accuracy: 1.0
#
# Iter: 84
# Class name: Collector Nagar ; No. of Images: 2
# Predicted as:  Collector Nagar,  Collector Nagar,
# Groundtruth: Collector Nagar
# Accuracy: 1.0
#
# Iter: 85
# Class name: Anna Nagar West Depot ; No. of Images: 2
# Predicted as:  Anna Nagar West Depot,  Mogappair,
# Groundtruth: Anna Nagar West Depot
# Accuracy: 0.5
# Fetching New Image
# Predicted as :  Anna Nagar West Depot,  Mogappair,  Anna Nagar West Depot,
# Ground Truth: Anna Nagar West Depot
# Accuracy now is: 0.666666666667
#
# Iter: 86
# Class name: JJ Nagar East ; No. of Images: 2
# Predicted as:  JJ Nagar East,  JJ Nagar East,
# Groundtruth: JJ Nagar East
# Accuracy: 1.0
#
# Iter: 87
# Class name: Mogappair ; No. of Images: 2
# Predicted as:  Mogappair,  Mogappair,
# Groundtruth: Mogappair
# Accuracy: 1.0
#
# Iter: 88
# Class name: Incubation Centre ; No. of Images: 2
# Predicted as:  Incubation Centre,  Incubation Centre,
# Groundtruth: Incubation Centre
# Accuracy: 1.0
#
# Iter: 89
# Class name: Gurunath Stores ; No. of Images: 2
# Predicted as:  Gurunath Stores,  Gurunath Stores,
# Groundtruth: Gurunath Stores
# Accuracy: 1.0
#
# Iter: 90
# Class name: JJ Nagar East ; No. of Images: 2
# Predicted as:  JJ Nagar East,  JJ Nagar East,
# Groundtruth: JJ Nagar East
# Accuracy: 1.0
#
# Iter: 91
# Class name: Mogappair ; No. of Images: 2
# Predicted as:  Mogappair,  Mogappair,
# Groundtruth: Mogappair
# Accuracy: 1.0
#
# Iter: 92
# Class name: Gurunath Stores ; No. of Images: 2
# Predicted as:  Gurunath Stores,  Gurunath Stores,
# Groundtruth: Gurunath Stores
# Accuracy: 1.0
#
# Iter: 93
# Class name: Incubation Centre ; No. of Images: 2
# Predicted as:  Incubation Centre,  Incubation Centre,
# Groundtruth: Incubation Centre
# Accuracy: 1.0
#
# Iter: 94
# Class name: Incubation Centre ; No. of Images: 2
# Predicted as:  Incubation Centre,  Incubation Centre,
# Groundtruth: Incubation Centre
# Accuracy: 1.0
#
# Iter: 95
# Class name: Anna Nagar West Depot ; No. of Images: 2
# Predicted as:  Collector Nagar,  Collector Nagar,
# Groundtruth: Anna Nagar West Depot
# Accuracy: 1.0
#
# Iter: 96
# Class name: Thirumangalam ; No. of Images: 2
# Predicted as:  Thirumangalam,  Thirumangalam,
# Groundtruth: Thirumangalam
# Accuracy: 1.0
#
# Iter: 97
# Class name: Gurunath Stores ; No. of Images: 2
# Predicted as:  Gurunath Stores,  Gurunath Stores,
# Groundtruth: Gurunath Stores
# Accuracy: 1.0
#
# Iter: 98
# Class name: Thirumangalam ; No. of Images: 2
# Predicted as:  Thirumangalam,  Thirumangalam,
# Groundtruth: Thirumangalam
# Accuracy: 1.0
#
# Iter: 99
# Class name: Incubation Centre ; No. of Images: 2
# Predicted as:  Incubation Centre,  Incubation Centre,
# Groundtruth: Incubation Centre
# Accuracy: 1.0
#
# Time Taken: 1.00633406639
